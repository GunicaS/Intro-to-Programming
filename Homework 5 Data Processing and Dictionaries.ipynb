# %% [markdown]
# # Homework 5

# %%
#This program reads the happiness.csv file and turns it into a dictionary mapping country names with their index


def main():

    # Part 1
    # Build dictionary mapping countries to happiness index
    happy_dict = make_happy_dict()

    # Part 2
    # Print key value pairs sorted by key
    # Uncomment the function call below for part 2 only
    # print_sorted_dictionary(happy_dict)

    # Part 3
    # Uncomment the function call below for part 3 only
    # lookup happiness by country until the user enters done
    # lookup_happiness_by_country(happy_dict)

    # Parts 4-6 Uncomment the function call below for parts 4-6 Read
    # file containing population and GDP data and add happiness data
    # read_gdp_data(happy_dict)



def make_happy_dict():
    happydict = {}
    infile = open("happiness.csv","r") #opens the file
    infile.readline() #ignores the header 
    for line in infile: #loop
        line = line.strip()
        random = line.split(",")
        country = random[0] #assigns the columns into variables
        year = random[1]
        index = random[2]
        happydict[country] = index #assigns to dictionary
        print(country,index) #prints
    return happydict #returns function

def read_gdp_data(happy_dict):
    return

def lookup_happiness_by_country(happy_dict):
    return

# Function prints all the values in a dictionary d sorted by key
def print_sorted_dictionary(D):
    if type(D) != type({}):
        print("Dictionary not found")
        return
    print("Contents of dictionary sorted by key.")
    print("Key","Value")
    for key in sorted(D.keys()):
        print(key, D[key])
        
main()

# %%
#This program checks if the dictionary was correctly made by printing out the dictionary


def main():

    # Part 1
    # Build dictionary mapping countries to happiness index
    happy_dict = make_happy_dict()

    # Part 2
    # Print key value pairs sorted by key
    # Uncomment the function call below for part 2 only
    print_sorted_dictionary(happy_dict)

    # Part 3
    # Uncomment the function call below for part 3 only
    # lookup happiness by country until the user enters done
    # lookup_happiness_by_country(happy_dict)

    # Parts 4-6 Uncomment the function call below for parts 4-6 Read
    # file containing population and GDP data and add happiness data
    # read_gdp_data(happy_dict)



def make_happy_dict():
    happydict = {}
    infile = open("happiness.csv","r")
    infile.readline()
    for line in infile:
        line = line.strip()
        random = line.split(",")
        country = random[0]
        year = random[1]
        index = random[2]
        happydict[country] = index
        #print(country,index)
    return happydict

def read_gdp_data(happy_dict):
    return

def lookup_happiness_by_country(happy_dict):
    return

# Function prints all the values in a dictionary d sorted by key
def print_sorted_dictionary(D):
    if type(D) != type({}):
        print("Dictionary not found")
        return
    print("Contents of dictionary sorted by key.")
    print("Key","Value")
    for key in sorted(D.keys()):
        print(key, D[key])
        
main()

# %%
#This program asks the for the users input as a country and gives the happiness index

def main():

    # Part 1
    # Build dictionary mapping countries to happiness index
    happy_dict = make_happy_dict()

    # Part 2
    # Print key value pairs sorted by key
    # Uncomment the function call below for part 2 only
    # print_sorted_dictionary(happy_dict)

    # Part 3
    # Uncomment the function call below for part 3 only
    # lookup happiness by country until the user enters done
    lookup_happiness_by_country(happy_dict)

    # Parts 4-6 Uncomment the function call below for parts 4-6 Read
    # file containing population and GDP data and add happiness data
    # read_gdp_data(happy_dict)



def make_happy_dict():
    happydict = {}
    infile = open("happiness.csv","r")
    infile.readline()
    for line in infile:
        line = line.strip()
        random = line.split(",")
        country = random[0]
        year = random[1]
        index = random[2]
        happydict[country] = index
        #print(country,index)
    return happydict

def read_gdp_data(happy_dict):
    return

def lookup_happiness_by_country(happy_dict):
    happydict = {}
    infile = open("happiness.csv","r")
    for line in infile:
        line = line.strip()
        random = line.split(",")
        country = random[0]
        year = random[1]
        index = random[2]
        happydict[country] = index
    infile.close()
    while True:
        randoms = input("Enter a country to lookup or 'done' to exit:") #takes the user input
        if randoms == 'done': #if the user enters done the loop exists
            break
        if randoms in happydict: #if the country is in the dictionary the corresponding index is printed
            index = happydict[randoms]
            print(index)
        else: #else not found is printed
            print(randoms,"not found")
    return

# Function prints all the values in a dictionary d sorted by key
def print_sorted_dictionary(D):
    if type(D) != type({}):
        print("Dictionary not found")
        return
    print("Contents of dictionary sorted by key.")
    print("Key","Value")
    for key in sorted(D.keys()):
        print(key, D[key])

        
main()

# %%
#Takes the GDP data reformats it and then converts it into a dictionary
def main():

    # Part 1
    # Build dictionary mapping countries to happiness index
    happy_dict = make_happy_dict()

    # Part 2
    # Print key value pairs sorted by key
    # Uncomment the function call below for part 2 only
    # print_sorted_dictionary(happy_dict)

    # Part 3
    # Uncomment the function call below for part 3 only
    # lookup happiness by country until the user enters done
    # lookup_happiness_by_country(happy_dict)

    # Parts 4-6 Uncomment the function call below for parts 4-6 Read
    # file containing population and GDP data and add happiness data
    read_gdp_data(happy_dict)



def make_happy_dict():
    happydict = {}
    infile = open("happiness.csv","r")
    infile.readline()
    for line in infile:
        line = line.strip()
        random = line.split(",")
        country = random[0]
        year = random[1]
        index = random[2]
        happydict[country] = index
        #print(country,index)
    return happydict

def read_gdp_data(happy_dict):
    gdp = {} #makes an open dictionary
    infile = open("world_pop_gdp.tsv","r")
    for line in infile:
        line = line.strip()
        random = line.split("\t") #splits the spaces between the values
        country = random[0] #assigns variables to the dictionary
        population = random[1]
        money = random[2]
        gdp[country] = money #assigns the dictionary 
        moneyf = money.strip('$') #takes away the $ symbol from the money
        moneyg = moneyf.replace(',','') #replaces the commas with the blank spaces
        population1 = population.replace(',','') #replaces commas with blank spaces in the population
        print(country+","+population1+","+moneyg) #prints the final statement 
    return

def lookup_happiness_by_country(happy_dict):
    happydict = {}
    infile = open("happiness.csv","r")
    for line in infile:
        line = line.strip()
        random = line.split(",")
        country = random[0]
        year = random[1]
        index = random[2]
        happydict[country] = index
    infile.close()
    while True:
        randoms = input("Enter a country to lookup or 'done' to exit:")
        if randoms == 'done':
            break
        if randoms in happydict:
            index = happydict[randoms]
            print(index)
        else:
            print(randoms,"not found")
    return

# Function prints all the values in a dictionary d sorted by key
def print_sorted_dictionary(D):
    if type(D) != type({}):
        print("Dictionary not found")
        return
    print("Contents of dictionary sorted by key.")
    print("Key","Value")
    for key in sorted(D.keys()):
        print(key, D[key])

        
main()

# %%
#This program combines the dictionaries from the happiness csv and the GDP data

def main():

    # Part 1
    # Build dictionary mapping countries to happiness index
    happy_dict = make_happy_dict()

    # Part 2
    # Print key value pairs sorted by key
    # Uncomment the function call below for part 2 only
    # print_sorted_dictionary(happy_dict)

    # Part 3
    # Uncomment the function call below for part 3 only
    # lookup happiness by country until the user enters done
    # lookup_happiness_by_country(happy_dict)

    # Parts 4-6 Uncomment the function call below for parts 4-6 Read
    # file containing population and GDP data and add happiness data
    read_gdp_data(happy_dict)



def make_happy_dict():
    happydict = {}
    infile = open("happiness.csv","r")
    infile.readline()
    for line in infile:
        line = line.strip()
        random = line.split(",")
        country = random[0]
        year = random[1]
        index = random[2]
        happydict[country] = index
        #print(country,index)
    return happydict

def read_gdp_data(happy_dict):

    
    happydict = {}
    infile1 = open("happiness.csv","r")
    infile1.readline()

    gdp = {}
    infile2 = open("world_pop_gdp.tsv","r")
    infile2.readline()

    print ("Country,Population in Millions,GDP per Capita,Happiness") #prints the headline 
    
    for line in infile1:
        line = line.strip()
        random = line.split(",")
        country = random[0]
        year = random[1]
        index = random[2]
        happydict[country] = index
    
    for line in infile2:
        line = line.strip()
        random = line.split("\t")
        country1 = random[0]
        population = random[1]
        money = random[2]
        gdp[country] = money
        moneyf = money.strip('$')
        moneyg = moneyf.replace(',','')
        population1 = population.replace(',','')
        index2 = str(happy_dict.get(country1,0)) #uses the get function to get the other happiness dictionary
        if index2 == '0': #if a country does not have a happiness index it will be skipped
            continue
        print(country1+","+population1+","+moneyg+","+index2) #prints the final statement
    return

def lookup_happiness_by_country(happy_dict):
    happydict = {}
    infile = open("happiness.csv","r")
    for line in infile:
        line = line.strip()
        random = line.split(",")
        country = random[0]
        year = random[1]
        index = random[2]
        happydict[country] = index
    infile.close()
    while True:
        randoms = input("Enter a country to lookup or 'done' to exit:")
        if randoms == 'done':
            break
        if randoms in happydict:
            index = happydict=[randoms]
            print(index)
        else:
            print(randoms,"not found")
    return

# Function prints all the values in a dictionary d sorted by key
def print_sorted_dictionary(D):
    if type(D) != type({}):
        print("Dictionary not found")
        return
    print("Contents of dictionary sorted by key.")
    print("Key","Value")
    for key in sorted(D.keys()):
        print(key, D[key])

        
main()

# %%
#This program only prints out the countries that have a population more than 100 million


def main():

    # Part 1
    # Build dictionary mapping countries to happiness index
    happy_dict = make_happy_dict()

    # Part 2
    # Print key value pairs sorted by key
    # Uncomment the function call below for part 2 only
    # print_sorted_dictionary(happy_dict)

    # Part 3
    # Uncomment the function call below for part 3 only
    # lookup happiness by country until the user enters done
    # lookup_happiness_by_country(happy_dict)

    # Parts 4-6 Uncomment the function call below for parts 4-6 Read
    # file containing population and GDP data and add happiness data
    read_gdp_data(happy_dict)



def make_happy_dict():
    happydict = {}
    infile = open("happiness.csv","r")
    infile.readline()
    for line in infile:
        line = line.strip()
        random = line.split(",")
        country = random[0]
        year = random[1]
        index = random[2]
        happydict[country] = index
        #print(country,index)
    return happydict

def read_gdp_data(happy_dict):

    
    happydict = {}
    infile1 = open("happiness.csv","r")
    infile1.readline()

    gdp = {}
    infile2 = open("world_pop_gdp.tsv","r")
    infile2.readline()

    print ("Country,Population in Millions,GDP per Capita,Happiness")
    
    for line in infile1:
        line = line.strip()
        random = line.split(",")
        country = random[0]
        year = random[1]
        index = random[2]
        happydict[country] = index
    
    for line in infile2:
        line = line.strip()
        random = line.split("\t")
        country1 = random[0]
        population = random[1]
        money = random[2]
        gdp[country] = money
        moneyf = money.strip('$')
        moneyg = moneyf.replace(',','')
        population1 = population.replace(',','')
        index2 = str(happy_dict.get(country1,0))
        if index2 == '0':
            continue
        pop = float(population1) #converted population to a float so that it can be compared to 100 million
        if pop < 100: #make a loop for if the population if less than 100 million those countries will not be included
            continue      
        print(country1+","+str("{:.2f}".format(pop))+","+moneyg+","+index2) #the final population is reformatted to include 2 digits after decimal
    return

def lookup_happiness_by_country(happy_dict):
    happydict = {}
    infile = open("happiness.csv","r")
    for line in infile:
        line = line.strip()
        random = line.split(",")
        country = random[0]
        year = random[1]
        index = random[2]
        happydict[country] = index
    infile.close()
    while True:
        randoms = input("Enter a country to lookup or 'done' to exit:")
        if randoms == 'done':
            break
        if randoms in happydict:
            index = happydict=[randoms]
            print(index)
        else:
            print(randoms,"not found")
    return

# Function prints all the values in a dictionary d sorted by key
def print_sorted_dictionary(D):
    if type(D) != type({}):
        print("Dictionary not found")
        return
    print("Contents of dictionary sorted by key.")
    print("Key","Value")
    for key in sorted(D.keys()):
        print(key, D[key])

        
main()
